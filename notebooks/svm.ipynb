# %%
# https://stackabuse.com/implementing-svm-and-kernel-svm-with-pythons-scikit-learn/
# https://scikit-learn.org/stable/modules/svm.html
# https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# %%
# %load_ext autoreload

# %%
# %autoreload 1

import numpy as np
import pandas as pd

from sklearn import svm
from sklearn.svm import SVC

from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedShuffleSplit

from sklearn.preprocessing import normalize
from sklearn.preprocessing import StandardScaler

from src.displayResults import DisplayResults

from IPython.display import display

# %%
"""""""""""""""""""""""
" Constantes
"""""""""""""""""""""""

# Le fichier CSV contenant les données galaxies
csv_vectors = 'data/processed/galaxy_feature_vectors.csv'

kfold = 5   
ram = 1048   # Taille de la memoire vive
size = 0.2   # Taille des donnees  
nb_exec = 5  # Proportionnel au nb. de coeurs x86 de la machine

# Memoire vive à utiliser
cache = SVC(cache_size = ram)

# Variables et gamma
C = [1e-3, 1e-1, 1, 10]
gamma = C

# Facilite simplement l'affichage du tableau des resultats
variables_c = ['1e-3', '1e-1', '1.0', '10.0']

# DisplayResults possède la code pour afficher les tableaux
dr = DisplayResults()

# %%
"""""""""""""""""""""""
" Lecture fichiers CSV
"""""""""""""""""""""""
# Recupere les données galaxies (saute la premiere et derniere colonne --> ID galaxie)
X_galaxy = pd.read_csv(csv_vectors, header=None).values[:,1:-1]

# Recupere la colonne indiquant si c'est une galaxie spiral (1) ou smooth (0)
Y_galaxy = pd.read_csv(csv_vectors, header=None).values[:,-1:].astype(int).flatten()

# %%
"""""""""""""""""""""""
" Normalisation
"""""""""""""""""""""""

scaler = StandardScaler()

X_galaxy = scaler.fit_transform(X_galaxy)

# %%
def get_train_split_indices(x, test_size=0.2):
    
    x_train, x_test = train_test_split(x, test_size=test_size, shuffle=True)
    
    train_indexes = [x.index(elem) for elem in x_train]
    test_indexes = [x.index(elem) for elem in x_test]

    validator = [(train_indexes, test_indexes)]
    return validator

def svm_grid_search(X, Y, tuned_parameters):

    validator = get_train_split_indices(X.tolist())
    
    tuned_model = GridSearchCV(
        cache, 
        cv=validator, 
        verbose=4, 
        n_jobs=-1, 
        scoring=['accuracy', 'f1'], 
        refit='f1',
        return_train_score=True,
        param_grid=tuned_parameters
    )
    
    tuned_model.fit(X, Y)
    
    return tuned_model
    

"""""""""""""""""""""""
" GridSearch SVM linear
"""""""""""""""""""""""
def linear_grid_search(X, Y):
    """
    Fonction qui effectue un 'Grid Search' linéaire SVM 
    sur le jeu de données d'apprentissage.
    
    args:
        X:  matrice des données galaxies
        Y:  liste des étiquettes (type de galaxie)
    
    returns:
        La matrice SVM lineaire
    """
    
    tuned_parameters = {'kernel': ['linear'], 
                        'C': C,
                        'class_weight': ['balanced'],
                        'gamma': ['scale']}
    
    return svm_grid_search(X, Y, tuned_parameters)



"""""""""""""""""""""""""""
" GridSearch SVM N-linear
"""""""""""""""""""""""""""
def rbf_grid_search(X,Y):
    """
    Fonction qui effectue un 'Grid Search' non-linéaire SVM (rbf)
    sur le jeu de données d'apprentissage.
    
    args:
        X:  matrice des données galaxies
        Y:  liste des étiquettes (type de galaxie)
    
    returns:
        La matrice SVM non-lineaire (rbf)
    """
    
    tuned_parameters = {'kernel': ['rbf'], 
                        'C': C, 
                        'gamma': gamma}
    
    return svm_grid_search(X, Y, tuned_parameters)

# %%
"""""""""""""""""""""""""""
" Recupere les matrices SVM
"""""""""""""""""""""""""""

# Recupere les resultats SVM lineaire
linear_matrix = linear_grid_search(X_galaxy, Y_galaxy)

# Recupere les resultats SVM non-lineaire (rbf)
rbf_matrix = rbf_grid_search(X_galaxy, Y_galaxy)
# Out:
# Fitting 1 folds for each of 4 candidates, totalling 4 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:   28.2s finished
# Fitting 1 folds for each of 16 candidates, totalling 16 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of  16 | elapsed:  3.6min remaining:  5.9min
# /home/marc/anaconda3/envs/ml/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done  11 out of  16 | elapsed:  3.7min remaining:  1.7min
# [Parallel(n_jobs=-1)]: Done  16 out of  16 | elapsed:  5.4min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  16 out of  16 | elapsed:  5.4min finished

# %%
# %aimport src.displayResults

"""""""""""""""""""""""""""""""""""""""
" Affiche les resultats SVM lineaire
"""""""""""""""""""""""""""""""""""""""

print("***************************************************")
print("* SVM LINEAIRE")
print("*\n* Best accuracy: ", linear_matrix.best_score_)
print("* Best params. : ", linear_matrix.best_params_)
print("***************************************************")

train_accuracy = linear_matrix.cv_results_['mean_train_accuracy']
test_accuracy = linear_matrix.cv_results_['mean_test_accuracy']
train_f1 = linear_matrix.cv_results_['mean_train_f1']
test_f1 = linear_matrix.cv_results_['mean_test_f1']
fit_time = linear_matrix.cv_results_['mean_fit_time']

dr.svm_linear_table(
    variables_c, 
    train_accuracy, 
    test_accuracy,
    train_f1,
    test_f1,
    fit_time
)
# Out:
# ***************************************************
# * SVM LINEAIRE
# *
# * Best accuracy:  0.9529709940861729
# * Best params. :  {'C': 10, 'class_weight': 'balanced', 'gamma': 'scale', 'kernel': 'linear'}
# ***************************************************
# <style  type="text/css" >
#     #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row0_col0 {
#             width:  50px;
#             text-align:  left;
#         }    #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row0_col1 {
#             width:  100px;
#             text-align:  left;
#         }    #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row0_col2 {
#             width:  100px;
#             text-align:  left;
#         }    #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row0_col3 {
#             width:  100px;
#             text-align:  left;
#         }    #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row0_col4 {
#             width:  100px;
#             text-align:  left;
#         }    #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row0_col5 {
#             width:  125px;
#             text-align:  left;
#         }    #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row1_col0 {
#             width:  50px;
#             text-align:  left;
#         }    #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row1_col1 {
#             width:  100px;
#             text-align:  left;
#         }    #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row1_col2 {
#             width:  100px;
#             text-align:  left;
#         }    #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row1_col3 {
#             width:  100px;
#             text-align:  left;
#         }    #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row1_col4 {
#             width:  100px;
#             text-align:  left;
#         }    #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row1_col5 {
#             width:  125px;
#             text-align:  left;
#         }    #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row2_col0 {
#             width:  50px;
#             text-align:  left;
#         }    #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row2_col1 {
#             width:  100px;
#             text-align:  left;
#         }    #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row2_col2 {
#             width:  100px;
#             text-align:  left;
#         }    #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row2_col3 {
#             width:  100px;
#             text-align:  left;
#         }    #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row2_col4 {
#             width:  100px;
#             text-align:  left;
#         }    #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row2_col5 {
#             width:  125px;
#             text-align:  left;
#         }    #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row3_col0 {
#             width:  50px;
#             text-align:  left;
#         }    #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row3_col1 {
#             width:  100px;
#             text-align:  left;
#         }    #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row3_col2 {
#             width:  100px;
#             text-align:  left;
#         }    #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row3_col3 {
#             width:  100px;
#             text-align:  left;
#         }    #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row3_col4 {
#             width:  100px;
#             text-align:  left;
#         }    #T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row3_col5 {
#             width:  125px;
#             text-align:  left;
#         }</style><table id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >C</th>        <th class="col_heading level0 col1" >Train Accuracy</th>        <th class="col_heading level0 col2" >Test Accuracy</th>        <th class="col_heading level0 col3" >Train F1</th>        <th class="col_heading level0 col4" >Test F1</th>        <th class="col_heading level0 col5" >Fitting Time (sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row0_col0" class="data row0 col0" >1e-3</td>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row0_col1" class="data row0 col1" >0.93479225</td>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row0_col2" class="data row0 col2" >0.93287995</td>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row0_col3" class="data row0 col3" >0.93654676</td>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row0_col4" class="data row0 col4" >0.93596615</td>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row0_col5" class="data row0 col5" >10.879574</td>
#             </tr>
#             <tr>
#                         <th id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row1_col0" class="data row1 col0" >1e-1</td>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row1_col1" class="data row1 col1" >0.95061363</td>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row1_col2" class="data row1 col2" >0.94914252</td>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row1_col3" class="data row1 col3" >0.95194245</td>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row1_col4" class="data row1 col4" >0.95149464</td>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row1_col5" class="data row1 col5" >7.4746654</td>
#             </tr>
#             <tr>
#                         <th id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row2_col0" class="data row2 col0" >1.0</td>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row2_col1" class="data row2 col1" >0.95246193</td>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row2_col2" class="data row2 col2" >0.95062093</td>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row2_col3" class="data row2 col3" >0.95377759</td>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row2_col4" class="data row2 col4" >0.95294449</td>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row2_col5" class="data row2 col5" >10.395484</td>
#             </tr>
#             <tr>
#                         <th id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row3_col0" class="data row3 col0" >10.0</td>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row3_col1" class="data row3 col1" >0.95231406</td>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row3_col2" class="data row3 col2" >0.95062093</td>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row3_col3" class="data row3 col3" >0.95372031</td>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row3_col4" class="data row3 col4" >0.95297099</td>
#                         <td id="T_e05bbd14_a2aa_11e9_b360_74ea3ab42007row3_col5" class="data row3 col5" >24.747364</td>
#             </tr>
#     </tbody></table>

# %%
# %aimport src.displayResults

"""""""""""""""""""""""""""""""""""""""
" Affiche les resultats SVM N-lineaire
"""""""""""""""""""""""""""""""""""""""

print("***************************************************")
print("* SVM NON-LINEAIRE (RBF)")
print("*\n* Best accuracy: ", rbf_matrix.best_score_)
print("* Best params. : ", rbf_matrix.best_params_)
print("***************************************************")

train_accuracy = rbf_matrix.cv_results_['mean_train_accuracy']
test_accuracy = rbf_matrix.cv_results_['mean_test_accuracy']
train_f1 = rbf_matrix.cv_results_['mean_train_f1']
test_f1 = rbf_matrix.cv_results_['mean_test_f1']
fit_time = rbf_matrix.cv_results_['mean_fit_time']

print("\n *** Sigma Train Accuracy ***")
dr.svm_rbf_table(variables_c , train_accuracy)

print("\n *** Sigma Test Accuracy ***")
dr.svm_rbf_table(variables_c , test_accuracy)

print("\n *** Sigma Train F1 ***")
dr.svm_rbf_table(variables_c , train_f1)

print("\n *** Sigma Test F1 ***")
dr.svm_rbf_table(variables_c , test_f1)

print("\n *** Sigma Fitting Time (sec) ***")
dr.svm_rbf_table(variables_c , fit_time)
# Out:
# ***************************************************
# * SVM NON-LINEAIRE (RBF)
# *
# * Best accuracy:  0.956248212753789
# * Best params. :  {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# ***************************************************
#
#  *** Sigma Train Accuracy ***
# <style  type="text/css" >
#     #T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row0_col0 {
#             width:  60px;
#             text-align:  left;
#         }    #T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row0_col1 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row0_col2 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row0_col3 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row0_col4 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row1_col0 {
#             width:  60px;
#             text-align:  left;
#         }    #T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row1_col1 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row1_col2 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row1_col3 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row1_col4 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row2_col0 {
#             width:  60px;
#             text-align:  left;
#         }    #T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row2_col1 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row2_col2 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row2_col3 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row2_col4 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row3_col0 {
#             width:  60px;
#             text-align:  left;
#         }    #T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row3_col1 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row3_col2 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row3_col3 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row3_col4 {
#             width:  80px;
#             text-align:  left;
#         }</style><table id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >C/sigma</th>        <th class="col_heading level0 col1" >1e-3</th>        <th class="col_heading level0 col2" >1e-1</th>        <th class="col_heading level0 col3" >1.0</th>        <th class="col_heading level0 col4" >10.0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row0_col0" class="data row0 col0" >1e-3</td>
#                         <td id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row0_col1" class="data row0 col1" >0.5193701</td>
#                         <td id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row0_col2" class="data row0 col2" >0.5193701</td>
#                         <td id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row0_col3" class="data row0 col3" >0.5193701</td>
#                         <td id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row0_col4" class="data row0 col4" >0.5193701</td>
#             </tr>
#             <tr>
#                         <th id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row1_col0" class="data row1 col0" >1e-1</td>
#                         <td id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row1_col1" class="data row1 col1" >0.91431317</td>
#                         <td id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row1_col2" class="data row1 col2" >0.91083839</td>
#                         <td id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row1_col3" class="data row1 col3" >0.5193701</td>
#                         <td id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row1_col4" class="data row1 col4" >0.5193701</td>
#             </tr>
#             <tr>
#                         <th id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row2_col0" class="data row2 col0" >1.0</td>
#                         <td id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row2_col1" class="data row2 col1" >0.94928286</td>
#                         <td id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row2_col2" class="data row2 col2" >0.99208931</td>
#                         <td id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row2_col3" class="data row2 col3" >1</td>
#                         <td id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row2_col4" class="data row2 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row3_col0" class="data row3 col0" >10.0</td>
#                         <td id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row3_col1" class="data row3 col1" >0.96229484</td>
#                         <td id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row3_col2" class="data row3 col2" >1</td>
#                         <td id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row3_col3" class="data row3 col3" >1</td>
#                         <td id="T_b28ebfb6_a2ab_11e9_b360_74ea3ab42007row3_col4" class="data row3 col4" >1</td>
#             </tr>
#     </tbody></table>
#  *** Sigma Test Accuracy ***
# <style  type="text/css" >
#     #T_b2924a82_a2ab_11e9_b360_74ea3ab42007row0_col0 {
#             width:  60px;
#             text-align:  left;
#         }    #T_b2924a82_a2ab_11e9_b360_74ea3ab42007row0_col1 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2924a82_a2ab_11e9_b360_74ea3ab42007row0_col2 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2924a82_a2ab_11e9_b360_74ea3ab42007row0_col3 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2924a82_a2ab_11e9_b360_74ea3ab42007row0_col4 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2924a82_a2ab_11e9_b360_74ea3ab42007row1_col0 {
#             width:  60px;
#             text-align:  left;
#         }    #T_b2924a82_a2ab_11e9_b360_74ea3ab42007row1_col1 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2924a82_a2ab_11e9_b360_74ea3ab42007row1_col2 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2924a82_a2ab_11e9_b360_74ea3ab42007row1_col3 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2924a82_a2ab_11e9_b360_74ea3ab42007row1_col4 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2924a82_a2ab_11e9_b360_74ea3ab42007row2_col0 {
#             width:  60px;
#             text-align:  left;
#         }    #T_b2924a82_a2ab_11e9_b360_74ea3ab42007row2_col1 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2924a82_a2ab_11e9_b360_74ea3ab42007row2_col2 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2924a82_a2ab_11e9_b360_74ea3ab42007row2_col3 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2924a82_a2ab_11e9_b360_74ea3ab42007row2_col4 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2924a82_a2ab_11e9_b360_74ea3ab42007row3_col0 {
#             width:  60px;
#             text-align:  left;
#         }    #T_b2924a82_a2ab_11e9_b360_74ea3ab42007row3_col1 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2924a82_a2ab_11e9_b360_74ea3ab42007row3_col2 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2924a82_a2ab_11e9_b360_74ea3ab42007row3_col3 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2924a82_a2ab_11e9_b360_74ea3ab42007row3_col4 {
#             width:  80px;
#             text-align:  left;
#         }</style><table id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >C/sigma</th>        <th class="col_heading level0 col1" >1e-3</th>        <th class="col_heading level0 col2" >1e-1</th>        <th class="col_heading level0 col3" >1.0</th>        <th class="col_heading level0 col4" >10.0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007row0_col0" class="data row0 col0" >1e-3</td>
#                         <td id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007row0_col1" class="data row0 col1" >0.51774098</td>
#                         <td id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007row0_col2" class="data row0 col2" >0.51774098</td>
#                         <td id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007row0_col3" class="data row0 col3" >0.51774098</td>
#                         <td id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007row0_col4" class="data row0 col4" >0.51774098</td>
#             </tr>
#             <tr>
#                         <th id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007row1_col0" class="data row1 col0" >1e-1</td>
#                         <td id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007row1_col1" class="data row1 col1" >0.91927853</td>
#                         <td id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007row1_col2" class="data row1 col2" >0.89769367</td>
#                         <td id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007row1_col3" class="data row1 col3" >0.51774098</td>
#                         <td id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007row1_col4" class="data row1 col4" >0.51774098</td>
#             </tr>
#             <tr>
#                         <th id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007row2_col0" class="data row2 col0" >1.0</td>
#                         <td id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007row2_col1" class="data row2 col1" >0.94589001</td>
#                         <td id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007row2_col2" class="data row2 col2" >0.94056771</td>
#                         <td id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007row2_col3" class="data row2 col3" >0.60733294</td>
#                         <td id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007row2_col4" class="data row2 col4" >0.51774098</td>
#             </tr>
#             <tr>
#                         <th id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007row3_col0" class="data row3 col0" >10.0</td>
#                         <td id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007row3_col1" class="data row3 col1" >0.9547605</td>
#                         <td id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007row3_col2" class="data row3 col2" >0.94382022</td>
#                         <td id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007row3_col3" class="data row3 col3" >0.62921348</td>
#                         <td id="T_b2924a82_a2ab_11e9_b360_74ea3ab42007row3_col4" class="data row3 col4" >0.51774098</td>
#             </tr>
#     </tbody></table>
#  *** Sigma Train F1 ***
# <style  type="text/css" >
#     #T_b294d450_a2ab_11e9_b360_74ea3ab42007row0_col0 {
#             width:  60px;
#             text-align:  left;
#         }    #T_b294d450_a2ab_11e9_b360_74ea3ab42007row0_col1 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b294d450_a2ab_11e9_b360_74ea3ab42007row0_col2 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b294d450_a2ab_11e9_b360_74ea3ab42007row0_col3 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b294d450_a2ab_11e9_b360_74ea3ab42007row0_col4 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b294d450_a2ab_11e9_b360_74ea3ab42007row1_col0 {
#             width:  60px;
#             text-align:  left;
#         }    #T_b294d450_a2ab_11e9_b360_74ea3ab42007row1_col1 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b294d450_a2ab_11e9_b360_74ea3ab42007row1_col2 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b294d450_a2ab_11e9_b360_74ea3ab42007row1_col3 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b294d450_a2ab_11e9_b360_74ea3ab42007row1_col4 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b294d450_a2ab_11e9_b360_74ea3ab42007row2_col0 {
#             width:  60px;
#             text-align:  left;
#         }    #T_b294d450_a2ab_11e9_b360_74ea3ab42007row2_col1 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b294d450_a2ab_11e9_b360_74ea3ab42007row2_col2 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b294d450_a2ab_11e9_b360_74ea3ab42007row2_col3 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b294d450_a2ab_11e9_b360_74ea3ab42007row2_col4 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b294d450_a2ab_11e9_b360_74ea3ab42007row3_col0 {
#             width:  60px;
#             text-align:  left;
#         }    #T_b294d450_a2ab_11e9_b360_74ea3ab42007row3_col1 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b294d450_a2ab_11e9_b360_74ea3ab42007row3_col2 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b294d450_a2ab_11e9_b360_74ea3ab42007row3_col3 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b294d450_a2ab_11e9_b360_74ea3ab42007row3_col4 {
#             width:  80px;
#             text-align:  left;
#         }</style><table id="T_b294d450_a2ab_11e9_b360_74ea3ab42007" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >C/sigma</th>        <th class="col_heading level0 col1" >1e-3</th>        <th class="col_heading level0 col2" >1e-1</th>        <th class="col_heading level0 col3" >1.0</th>        <th class="col_heading level0 col4" >10.0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b294d450_a2ab_11e9_b360_74ea3ab42007level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b294d450_a2ab_11e9_b360_74ea3ab42007row0_col0" class="data row0 col0" >1e-3</td>
#                         <td id="T_b294d450_a2ab_11e9_b360_74ea3ab42007row0_col1" class="data row0 col1" >0.68366503</td>
#                         <td id="T_b294d450_a2ab_11e9_b360_74ea3ab42007row0_col2" class="data row0 col2" >0.68366503</td>
#                         <td id="T_b294d450_a2ab_11e9_b360_74ea3ab42007row0_col3" class="data row0 col3" >0.68366503</td>
#                         <td id="T_b294d450_a2ab_11e9_b360_74ea3ab42007row0_col4" class="data row0 col4" >0.68366503</td>
#             </tr>
#             <tr>
#                         <th id="T_b294d450_a2ab_11e9_b360_74ea3ab42007level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b294d450_a2ab_11e9_b360_74ea3ab42007row1_col0" class="data row1 col0" >1e-1</td>
#                         <td id="T_b294d450_a2ab_11e9_b360_74ea3ab42007row1_col1" class="data row1 col1" >0.9175617</td>
#                         <td id="T_b294d450_a2ab_11e9_b360_74ea3ab42007row1_col2" class="data row1 col2" >0.91961072</td>
#                         <td id="T_b294d450_a2ab_11e9_b360_74ea3ab42007row1_col3" class="data row1 col3" >0.68366503</td>
#                         <td id="T_b294d450_a2ab_11e9_b360_74ea3ab42007row1_col4" class="data row1 col4" >0.68366503</td>
#             </tr>
#             <tr>
#                         <th id="T_b294d450_a2ab_11e9_b360_74ea3ab42007level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b294d450_a2ab_11e9_b360_74ea3ab42007row2_col0" class="data row2 col0" >1.0</td>
#                         <td id="T_b294d450_a2ab_11e9_b360_74ea3ab42007row2_col1" class="data row2 col1" >0.9511396</td>
#                         <td id="T_b294d450_a2ab_11e9_b360_74ea3ab42007row2_col2" class="data row2 col2" >0.99239463</td>
#                         <td id="T_b294d450_a2ab_11e9_b360_74ea3ab42007row2_col3" class="data row2 col3" >1</td>
#                         <td id="T_b294d450_a2ab_11e9_b360_74ea3ab42007row2_col4" class="data row2 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_b294d450_a2ab_11e9_b360_74ea3ab42007level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b294d450_a2ab_11e9_b360_74ea3ab42007row3_col0" class="data row3 col0" >10.0</td>
#                         <td id="T_b294d450_a2ab_11e9_b360_74ea3ab42007row3_col1" class="data row3 col1" >0.96368556</td>
#                         <td id="T_b294d450_a2ab_11e9_b360_74ea3ab42007row3_col2" class="data row3 col2" >1</td>
#                         <td id="T_b294d450_a2ab_11e9_b360_74ea3ab42007row3_col3" class="data row3 col3" >1</td>
#                         <td id="T_b294d450_a2ab_11e9_b360_74ea3ab42007row3_col4" class="data row3 col4" >1</td>
#             </tr>
#     </tbody></table>
#  *** Sigma Test F1 ***
# <style  type="text/css" >
#     #T_b2975e82_a2ab_11e9_b360_74ea3ab42007row0_col0 {
#             width:  60px;
#             text-align:  left;
#         }    #T_b2975e82_a2ab_11e9_b360_74ea3ab42007row0_col1 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2975e82_a2ab_11e9_b360_74ea3ab42007row0_col2 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2975e82_a2ab_11e9_b360_74ea3ab42007row0_col3 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2975e82_a2ab_11e9_b360_74ea3ab42007row0_col4 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2975e82_a2ab_11e9_b360_74ea3ab42007row1_col0 {
#             width:  60px;
#             text-align:  left;
#         }    #T_b2975e82_a2ab_11e9_b360_74ea3ab42007row1_col1 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2975e82_a2ab_11e9_b360_74ea3ab42007row1_col2 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2975e82_a2ab_11e9_b360_74ea3ab42007row1_col3 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2975e82_a2ab_11e9_b360_74ea3ab42007row1_col4 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2975e82_a2ab_11e9_b360_74ea3ab42007row2_col0 {
#             width:  60px;
#             text-align:  left;
#         }    #T_b2975e82_a2ab_11e9_b360_74ea3ab42007row2_col1 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2975e82_a2ab_11e9_b360_74ea3ab42007row2_col2 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2975e82_a2ab_11e9_b360_74ea3ab42007row2_col3 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2975e82_a2ab_11e9_b360_74ea3ab42007row2_col4 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2975e82_a2ab_11e9_b360_74ea3ab42007row3_col0 {
#             width:  60px;
#             text-align:  left;
#         }    #T_b2975e82_a2ab_11e9_b360_74ea3ab42007row3_col1 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2975e82_a2ab_11e9_b360_74ea3ab42007row3_col2 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2975e82_a2ab_11e9_b360_74ea3ab42007row3_col3 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b2975e82_a2ab_11e9_b360_74ea3ab42007row3_col4 {
#             width:  80px;
#             text-align:  left;
#         }</style><table id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >C/sigma</th>        <th class="col_heading level0 col1" >1e-3</th>        <th class="col_heading level0 col2" >1e-1</th>        <th class="col_heading level0 col3" >1.0</th>        <th class="col_heading level0 col4" >10.0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007row0_col0" class="data row0 col0" >1e-3</td>
#                         <td id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007row0_col1" class="data row0 col1" >0.68225209</td>
#                         <td id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007row0_col2" class="data row0 col2" >0.68225209</td>
#                         <td id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007row0_col3" class="data row0 col3" >0.68225209</td>
#                         <td id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007row0_col4" class="data row0 col4" >0.68225209</td>
#             </tr>
#             <tr>
#                         <th id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007row1_col0" class="data row1 col0" >1e-1</td>
#                         <td id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007row1_col1" class="data row1 col1" >0.92143885</td>
#                         <td id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007row1_col2" class="data row1 col2" >0.90797872</td>
#                         <td id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007row1_col3" class="data row1 col3" >0.68225209</td>
#                         <td id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007row1_col4" class="data row1 col4" >0.68225209</td>
#             </tr>
#             <tr>
#                         <th id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007row2_col0" class="data row2 col0" >1.0</td>
#                         <td id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007row2_col1" class="data row2 col1" >0.94751936</td>
#                         <td id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007row2_col2" class="data row2 col2" >0.94405789</td>
#                         <td id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007row2_col3" class="data row2 col3" >0.72493786</td>
#                         <td id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007row2_col4" class="data row2 col4" >0.68225209</td>
#             </tr>
#             <tr>
#                         <th id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007row3_col0" class="data row3 col0" >10.0</td>
#                         <td id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007row3_col1" class="data row3 col1" >0.95624821</td>
#                         <td id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007row3_col2" class="data row3 col2" >0.94692737</td>
#                         <td id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007row3_col3" class="data row3 col3" >0.73611111</td>
#                         <td id="T_b2975e82_a2ab_11e9_b360_74ea3ab42007row3_col4" class="data row3 col4" >0.68225209</td>
#             </tr>
#     </tbody></table>
#  *** Sigma Fitting Time (sec) ***
# <style  type="text/css" >
#     #T_b299caaa_a2ab_11e9_b360_74ea3ab42007row0_col0 {
#             width:  60px;
#             text-align:  left;
#         }    #T_b299caaa_a2ab_11e9_b360_74ea3ab42007row0_col1 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b299caaa_a2ab_11e9_b360_74ea3ab42007row0_col2 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b299caaa_a2ab_11e9_b360_74ea3ab42007row0_col3 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b299caaa_a2ab_11e9_b360_74ea3ab42007row0_col4 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b299caaa_a2ab_11e9_b360_74ea3ab42007row1_col0 {
#             width:  60px;
#             text-align:  left;
#         }    #T_b299caaa_a2ab_11e9_b360_74ea3ab42007row1_col1 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b299caaa_a2ab_11e9_b360_74ea3ab42007row1_col2 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b299caaa_a2ab_11e9_b360_74ea3ab42007row1_col3 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b299caaa_a2ab_11e9_b360_74ea3ab42007row1_col4 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b299caaa_a2ab_11e9_b360_74ea3ab42007row2_col0 {
#             width:  60px;
#             text-align:  left;
#         }    #T_b299caaa_a2ab_11e9_b360_74ea3ab42007row2_col1 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b299caaa_a2ab_11e9_b360_74ea3ab42007row2_col2 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b299caaa_a2ab_11e9_b360_74ea3ab42007row2_col3 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b299caaa_a2ab_11e9_b360_74ea3ab42007row2_col4 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b299caaa_a2ab_11e9_b360_74ea3ab42007row3_col0 {
#             width:  60px;
#             text-align:  left;
#         }    #T_b299caaa_a2ab_11e9_b360_74ea3ab42007row3_col1 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b299caaa_a2ab_11e9_b360_74ea3ab42007row3_col2 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b299caaa_a2ab_11e9_b360_74ea3ab42007row3_col3 {
#             width:  80px;
#             text-align:  left;
#         }    #T_b299caaa_a2ab_11e9_b360_74ea3ab42007row3_col4 {
#             width:  80px;
#             text-align:  left;
#         }</style><table id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >C/sigma</th>        <th class="col_heading level0 col1" >1e-3</th>        <th class="col_heading level0 col2" >1e-1</th>        <th class="col_heading level0 col3" >1.0</th>        <th class="col_heading level0 col4" >10.0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007row0_col0" class="data row0 col0" >1e-3</td>
#                         <td id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007row0_col1" class="data row0 col1" >89.626214</td>
#                         <td id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007row0_col2" class="data row0 col2" >95.767437</td>
#                         <td id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007row0_col3" class="data row0 col3" >70.56345</td>
#                         <td id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007row0_col4" class="data row0 col4" >91.161462</td>
#             </tr>
#             <tr>
#                         <th id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007row1_col0" class="data row1 col0" >1e-1</td>
#                         <td id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007row1_col1" class="data row1 col1" >36.567384</td>
#                         <td id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007row1_col2" class="data row1 col2" >39.637987</td>
#                         <td id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007row1_col3" class="data row1 col3" >89.096722</td>
#                         <td id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007row1_col4" class="data row1 col4" >87.614703</td>
#             </tr>
#             <tr>
#                         <th id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007row2_col0" class="data row2 col0" >1.0</td>
#                         <td id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007row2_col1" class="data row2 col1" >19.565106</td>
#                         <td id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007row2_col2" class="data row2 col2" >34.689949</td>
#                         <td id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007row2_col3" class="data row2 col3" >96.673056</td>
#                         <td id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007row2_col4" class="data row2 col4" >85.436692</td>
#             </tr>
#             <tr>
#                         <th id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007row3_col0" class="data row3 col0" >10.0</td>
#                         <td id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007row3_col1" class="data row3 col1" >14.802909</td>
#                         <td id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007row3_col2" class="data row3 col2" >24.690998</td>
#                         <td id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007row3_col3" class="data row3 col3" >52.605923</td>
#                         <td id="T_b299caaa_a2ab_11e9_b360_74ea3ab42007row3_col4" class="data row3 col4" >50.380447</td>
#             </tr>
#     </tbody></table>

# %%
# Exécution du modèle linéaire et avec RBF pour 100 %, 50 % et 25 % des données


linear_params = {
    'kernel': ['linear'], 
    'C': [1],
    'class_weight': ['balanced'],
    'gamma': ['scale']
}

rbf_params = {
    'kernel': ['rbf'], 
    'C': [10], 
    'gamma': [1e-3]
}

nb_x = len(X_galaxy)

linear_model_100p = svm_grid_search(X_galaxy, Y_galaxy, linear_params)
linear_model_50p = svm_grid_search(X_galaxy[:int(nb_x*0.50)], Y_galaxy[:int(nb_x*0.50)], linear_params)
linear_model_25p = svm_grid_search(X_galaxy[:int(nb_x*0.25)], Y_galaxy[:int(nb_x*0.25)], linear_params)

rbf_model_100p = svm_grid_search(X_galaxy, Y_galaxy, rbf_params)
rbf_model_50p = svm_grid_search(X_galaxy[:int(nb_x*0.50)], Y_galaxy[:int(nb_x*0.50)], rbf_params)
rbf_model_25p = svm_grid_search(X_galaxy[:int(nb_x*0.25)], Y_galaxy[:int(nb_x*0.25)], rbf_params)
# Out:
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:   12.4s finished
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    3.1s finished
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.8s finished
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:   10.4s finished
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    2.9s finished
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.8s finished

# %%
# Affichage des résultats de l'exécution avec 100 %, 50 % et 25 % des données

def format_results(model, run_name):
    
    return {
        'run name': run_name,
        'train accuracy': model.cv_results_['mean_train_accuracy'][0],
        'test accuracy': model.cv_results_['mean_test_accuracy'][0],
        'train F1': model.cv_results_['mean_train_f1'][0],
        'test F1': model.cv_results_['mean_test_f1'][0],
        'train time': model.cv_results_['mean_fit_time'][0]
    }

results = []

results.append(format_results(linear_model_100p, 'linear 100%'))
results.append(format_results(linear_model_50p, 'linear 50%'))
results.append(format_results(linear_model_25p, 'linear 25%'))
results.append(format_results(rbf_model_100p, 'RBF 100%'))
results.append(format_results(rbf_model_50p, 'RBF 50%'))
results.append(format_results(rbf_model_25p, 'RBF 25%'))

display(pd.DataFrame(results).transpose())
# Out:
#                           0           1           2         3         4  \
# run name        linear 100%  linear 50%  linear 25%  RBF 100%   RBF 50%
# test F1            0.947644    0.947964    0.958378  0.958766  0.956272
# test accuracy      0.946777    0.945594    0.953901  0.956535  0.955056
# train F1           0.954396    0.955527    0.949796  0.962466  0.958946
# train accuracy     0.952684    0.953423    0.949127  0.961112  0.956676
# train time           7.6606     1.67063    0.425889   4.17133   1.01289
#
#                        5
# run name         RBF 25%
# test F1         0.954955
# test accuracy   0.952719
# train F1        0.955053
# train accuracy  0.953564
# train time      0.287846
